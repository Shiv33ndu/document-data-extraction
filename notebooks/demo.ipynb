# %% [markdown]
# ## Rule-Based Extraction Prototype Demo

# %% [markdown]
# This notebook demonstrates the end-to-end document processing pipeline:
#
# Ingest → Text Extraction → Classification → Field Extraction → Structured Output
#
# The goal is to evaluate rule-based extraction across multiple document types and observe strengths and limitations on semi-structured PDFs.

# %%
import os
from pathlib import Path

# %%
# root path 
root_path = Path.cwd().parent

# %%
# change the working path to root path
os.chdir(root_path)

# %%
# essential imports

from src.ingest import discover_documents
from src.extract import extract_text_from_pdf, extract_fields_by_type
from src.classifier import classify_document
from src.utils import save_json
from src.pipeline import process_directory

# %%
# Paths 

input_dir = Path("data/samples2")
output_path = Path("results/results.json")

input_dir, output_path
# Out:
# (WindowsPath('data/samples2'), WindowsPath('results/results.json'))

# %% [markdown]
# ### Pipeline

# %%
results = process_directory(input_dir)

save_json(results, output_path)

print(f"Extraction complete! Results saved at: {output_path}")
# Out:
# Extraction complete! Results saved at: results\results.json

# %% [markdown]
# ### Results

# %%
import json

with open(output_path, "r", encoding="utf-8") as f:
    data = json.load(f)

data
# Out:
# [{'file_name': 'compliance_sample.pdf',
#   'document_type': 'compliance',
#   'fields': {'document_name': 'DATA PRIVACY COMPLIANCE POLICY Version: 2.1 Effective Date: 01 January 2026 Issued by: Compliance Department Regulation: GDPR (General Data Protection Regulation) Scope: This policy applies to all employees and contractors handling personal data. Requirements: - Personal data must be encrypted - Access must be restricted to authorized personnel - Data breaches must be reported within 72 hours Review Cycle: Annual',
#    'effective_date': '01',
#    'version': '2.1',
#    'regulatory_reference': 'GDPR (General Data Protection Regulation) Scope: This policy applies to all employees and contractors handling personal data. Requirements: - Personal data must be encrypted - Access must be restricted to authorized personnel - Data breaches must be reported within 72 hours Review Cycle: Annual',
#    'issuing_authority': 'Compliance Department Regulation: GDPR (General Data Protection Regulation) Scope: This policy applies to all employees and contractors handling personal data. Requirements: - Personal data must be encrypted - Access must be restricted to authorized personnel - Data breaches must be reported within 72 hours Review Cycle: Annual'}},
#  {'file_name': 'contract_sample.pdf',
#   'document_type': 'contract',
#   'fields': {'effective_date': '01 March 2026 Scope of Work',
#    'parties': 'Alpha Solutions Ltd. & Beta Technologies Inc'}},
#  {'file_name': 'email_sample.pdf',
#   'document_type': 'email',
#   'fields': {'from': 'alice@example.com To: bob@example.com Cc: team@example.com Sent: 18 Feb 2026 10:30 AM Subject: Project Kickoff Meeting Hi Bob, We will hold the project kickoff meeting on Monday at 2 PM. Please review the attached documents beforehand. Best regards, Alice Project Manager',
#    'to': 'bob@example.com Cc: team@example.com Sent: 18 Feb 2026 10:30 AM Subject: Project Kickoff Meeting Hi Bob, We will hold the project kickoff meeting on Monday at 2 PM. Please review the attached documents beforehand. Best regards, Alice Project Manager',
#    'subject': 'Project Kickoff Meeting Hi Bob, We will hold the project kickoff meeting on Monday at 2 PM. Please review the attached documents beforehand. Best regards, Alice Project Manager'}},
#  {'file_name': 'financial_statement.pdf',
#   'document_type': 'financial_statement',
#   'fields': {'total_assets': '350,000', 'total_liabilities': '150,000'}},
#  {'file_name': 'form_sample.pdf',
#   'document_type': 'form',
#   'fields': {'full_name': 'John Doe',
#    'date_of_birth': '12/05/1990',
#    'email_address': 'john.doe@example.com',
#    'phone_number': '+1-555-123-4567',
#    'address': '456 Elm Street',
#    'signature': '___________________',
#    'date': '20 Feb 2026'}},
#  {'file_name': 'invoice_sample.pdf',
#   'document_type': 'invoice',
#   'fields': {'invoice_number': 'Invoice',
#    'date': '15',
#    'total_amount': '3,700.00'}},
#  {'file_name': 'report_sample.pdf',
#   'document_type': 'report',
#   'fields': {'title': 'ANNUAL PERFORMANCE REPORT 2025 Prepared by: Data Insights Team Date: 31 January 2026 Executive Summary: The company experienced a 25% increase in revenue compared to the previous year. Customer retention improved significantly due to enhanced service quality. Key Findings: ● Revenue growth across all regions ● Expansion into two new markets ● Operational cost reduction by 8% Conclusion: Overall performance exceeded expectations.',
#    'executive_summary': ': The company experienced a 25% increase in revenue compared to the previous year. Customer retention improved significantly due to enhanced service quality. Key Findings: ● Revenue growth across all regions ● Expansion into two new markets ● Operational cost reduction by 8% Conclusion: Overall performance exceeded expectations.',
#    'date': '31',
#    'author': 'Data Insights Team Date: 31 January 2026 Executive Summary: The company experienced a 25% increase in revenue compared to the previous year. Customer retention improved significantly due to enhanced service quality. Key Findings: ● Revenue growth across all regions ● Expansion into two new markets ● Operational cost reduction by 8% Conclusion: Overall performance exceeded expectations.'}}]

# %% [markdown]
# ### Prettier Output

# %%
from pprint import pprint

for item in data:
    pprint(item)

    print("-" * 60)
# Out:
# {'document_type': 'compliance',
#  'fields': {'document_name': 'DATA PRIVACY COMPLIANCE POLICY Version: 2.1 '
#                              'Effective Date: 01 January 2026 Issued by: '
#                              'Compliance Department Regulation: GDPR (General '
#                              'Data Protection Regulation) Scope: This policy '
#                              'applies to all employees and contractors '
#                              'handling personal data. Requirements: - Personal '
#                              'data must be encrypted - Access must be '
#                              'restricted to authorized personnel - Data '
#                              'breaches must be reported within 72 hours Review '
#                              'Cycle: Annual',
#             'effective_date': '01',
#             'issuing_authority': 'Compliance Department Regulation: GDPR '
#                                  '(General Data Protection Regulation) Scope: '
#                                  'This policy applies to all employees and '
#                                  'contractors handling personal data. '
#                                  'Requirements: - Personal data must be '
#                                  'encrypted - Access must be restricted to '
#                                  'authorized personnel - Data breaches must be '
#                                  'reported within 72 hours Review Cycle: '
#                                  'Annual',
#             'regulatory_reference': 'GDPR (General Data Protection Regulation) '
#                                     'Scope: This policy applies to all '
#                                     'employees and contractors handling '
#                                     'personal data. Requirements: - Personal '
#                                     'data must be encrypted - Access must be '
#                                     'restricted to authorized personnel - Data '
#                                     'breaches must be reported within 72 hours '
#                                     'Review Cycle: Annual',
#             'version': '2.1'},
#  'file_name': 'compliance_sample.pdf'}
# ------------------------------------------------------------
# {'document_type': 'contract',
#  'fields': {'effective_date': '01 March 2026 Scope of Work',
#             'parties': 'Alpha Solutions Ltd. & Beta Technologies Inc'},
#  'file_name': 'contract_sample.pdf'}
# ------------------------------------------------------------
# {'document_type': 'email',
#  'fields': {'from': 'alice@example.com To: bob@example.com Cc: '
#                     'team@example.com Sent: 18 Feb 2026 10:30 AM Subject: '
#                     'Project Kickoff Meeting Hi Bob, We will hold the project '
#                     'kickoff meeting on Monday at 2 PM. Please review the '
#                     'attached documents beforehand. Best regards, Alice '
#                     'Project Manager',
#             'subject': 'Project Kickoff Meeting Hi Bob, We will hold the '
#                        'project kickoff meeting on Monday at 2 PM. Please '
#                        'review the attached documents beforehand. Best '
#                        'regards, Alice Project Manager',
#             'to': 'bob@example.com Cc: team@example.com Sent: 18 Feb 2026 '
#                   '10:30 AM Subject: Project Kickoff Meeting Hi Bob, We will '
#                   'hold the project kickoff meeting on Monday at 2 PM. Please '
#                   'review the attached documents beforehand. Best regards, '
#                   'Alice Project Manager'},
#  'file_name': 'email_sample.pdf'}
# ------------------------------------------------------------
# {'document_type': 'financial_statement',
#  'fields': {'total_assets': '350,000', 'total_liabilities': '150,000'},
#  'file_name': 'financial_statement.pdf'}
# ------------------------------------------------------------
# {'document_type': 'form',
#  'fields': {'address': '456 Elm Street',
#             'date': '20 Feb 2026',
#             'date_of_birth': '12/05/1990',
#             'email_address': 'john.doe@example.com',
#             'full_name': 'John Doe',
#             'phone_number': '+1-555-123-4567',
#             'signature': '___________________'},
#  'file_name': 'form_sample.pdf'}
# ------------------------------------------------------------
# {'document_type': 'invoice',
#  'fields': {'date': '15',
#             'invoice_number': 'Invoice',
#             'total_amount': '3,700.00'},
#  'file_name': 'invoice_sample.pdf'}
# ------------------------------------------------------------
# {'document_type': 'report',
#  'fields': {'author': 'Data Insights Team Date: 31 January 2026 Executive '
#                       'Summary: The company experienced a 25% increase in '
#                       'revenue compared to the previous year. Customer '
#                       'retention improved significantly due to enhanced '
#                       'service quality. Key Findings: ● Revenue growth across '
#                       'all regions ● Expansion into two new markets ● '
#                       'Operational cost reduction by 8% Conclusion: Overall '
#                       'performance exceeded expectations.',
#             'date': '31',
#             'executive_summary': ': The company experienced a 25% increase in '
#                                  'revenue compared to the previous year. '
#                                  'Customer retention improved significantly '
#                                  'due to enhanced service quality. Key '
#                                  'Findings: ● Revenue growth across all '
#                                  'regions ● Expansion into two new markets ● '
#                                  'Operational cost reduction by 8% Conclusion: '
#                                  'Overall performance exceeded expectations.',
#             'title': 'ANNUAL PERFORMANCE REPORT 2025 Prepared by: Data '
#                      'Insights Team Date: 31 January 2026 Executive Summary: '
#                      'The company experienced a 25% increase in revenue '
#                      'compared to the previous year. Customer retention '
#                      'improved significantly due to enhanced service quality. '
#                      'Key Findings: ● Revenue growth across all regions ● '
#                      'Expansion into two new markets ● Operational cost '
#                      'reduction by 8% Conclusion: Overall performance exceeded '
#                      'expectations.'},
#  'file_name': 'report_sample.pdf'}
# ------------------------------------------------------------
